# %% [markdown]
# # P-219- Hourly Energy Consumption Forecast
# The hourly power consumption data comes from PJM's website and are in megawatts (MW).

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing data and EDA Visuslization

# %%
df = pd.read_excel(r"C:\Users\visha\Downloads\PJMW_MW_Hourly.xlsx")
df
# Out:
#                   Datetime  PJMW_MW
# 0      2002-12-31 01:00:00     5077
# 1      2002-12-31 02:00:00     4939
# 2      2002-12-31 03:00:00     4885
# 3      2002-12-31 04:00:00     4857
# 4      2002-12-31 05:00:00     4930
# ...                    ...      ...
# 143201 2018-01-01 20:00:00     8401
# 143202 2018-01-01 21:00:00     8373
# 143203 2018-01-01 22:00:00     8238
# 143204 2018-01-01 23:00:00     7958
# 143205 2018-01-02 00:00:00     7691
#
# [143206 rows x 2 columns]

# %%
df.head()
# Out:
#              Datetime  PJMW_MW
# 0 2002-12-31 01:00:00     5077
# 1 2002-12-31 02:00:00     4939
# 2 2002-12-31 03:00:00     4885
# 3 2002-12-31 04:00:00     4857
# 4 2002-12-31 05:00:00     4930

# %%
df.describe()
# Out:
#              PJMW_MW
# count  143206.000000
# mean     5602.375089
# std       979.142872
# min       487.000000
# 25%      4907.000000
# 50%      5530.000000
# 75%      6252.000000
# max      9594.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143206 entries, 0 to 143205
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Datetime  143206 non-null  datetime64[ns]
#  1   PJMW_MW   143206 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.2 MB

# %%
df.dtypes
# Out:
# Datetime    datetime64[ns]
# PJMW_MW              int64
# dtype: object

# %%
df.shape
# Out:
# (143206, 2)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Datetime, PJMW_MW]
# Index: []

# %%
# !pip install dtale

# %%
#line plot
plt.figure(figsize=(8,4))
sns.lineplot(x = 'Datetime', y='PJMW_MW',data=df)
# Out:
# <AxesSubplot:xlabel='Datetime', ylabel='PJMW_MW'>

# %%
df.isnull().sum()
# Out:
# Datetime    0
# PJMW_MW     0
# dtype: int64

# %%
#Histogram
df.PJMW_MW.hist()
# Out:
# <AxesSubplot:>

# %%
df = df['PJMW_MW'].plot.hist(figsize=(15, 5), bins=200, title='Distribution of PJME Load')

# %%
#Distribution plot
sns.distplot(df['PJMW_MW'])
# Out:
# <AxesSubplot:xlabel='PJMW_MW', ylabel='Density'>

# %%
#kernalDensity plot
df.PJMW_MW.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.rcParams['figure.figsize']=(12,6)
plt.rcParams['figure.dpi']=300

sns.set_style('darkgrid')

# %%
plt.boxplot(df['PJMW_MW'], vert=False, patch_artist=True, showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23fef7bb190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23fef8bf100>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x23ff17ee610>],
#  'medians': [<matplotlib.lines.Line2D at 0x23fefd148b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23f80333be0>],
#  'means': [<matplotlib.lines.Line2D at 0x23ff17d9820>]}

# %% [markdown]
# # Plotting Time Series

# %%
plot = df.plot(style='.', figsize=(15, 8), title='Entire PJM Load 2002-2018')
